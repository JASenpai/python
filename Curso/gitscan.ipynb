# %%
'''
Rishov: @JASen  I want you to create a Python class that gets instantiated with a directory path and also takes in a text file containing the 
GitHub repo links that one has to paste onto a OS CLI to clone a Git repository on their local computer.

Rishov: @JASen  yeah the class has to look into the directory specified
by the user and a text file needs to be given which contains the github repo links. Then the class will clone them as soon as it is instantiated

class(directory) -> check that directory for txt files -> read url in txt files -> clone that url

'''

import sys
import os


class Gitclon:
        
    def __init__(self,dir):
        self.listas =[]
        for r, d, f in os.walk(dir):
            for file in f:
                if '.txt' in file:
                    self.listas.append(os.path.join(r, file))
                  
        print(self.listas, end= "\n")
        
               

    def clone(self, url):
        os.system('git clone '+ url)
        pass

    def openFile(self,archivo):
        file = open(archivo, "r")
        for line in file:
            self.clone(line)
        file.close()
        
    def enviara(self):
        for linea in self.listas:
            self.openFile(linea)
        
    
    def  searchTxt(self, path):
        listas =[]
        for r, d, f in os.walk(path.self):
            for file in f:
                if '.txt' in file:
                    listas.append(os.path.join(r, file))
        return(listas)
                    
                    
testdir =  os.getcwd() 
print("testdir")
print(testdir)

print("clase")
cloname = Gitclon(testdir)
cloname.enviara()
# Out:
# testdir
# /home/jschiavoni/GIT/Complete-Python-3-Bootcamp/misNotebooks
# clase
# ...
