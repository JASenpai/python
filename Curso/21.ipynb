# %%
class Card:
    
    def __init__(self,palo,numero):
        
        self.palo = palo
        self.numero = numero        
    
    def __str__(self):
        
        return self.palo + ' of ' + self.numero
    
    

class Deck:

    def __init__(self):
        self.deck = []  # start with an empty list
        for palo in suits:
            for numero in ranks:
                self.deck.append(Card(palo,numero))

    def __str__(self):
        deck_comp = ''  # start with an empty string
        for card in self.deck:
            deck_comp += '\n '+card.__str__() # add each Card object's print string
        return 'The deck has:' + deck_comp
    
    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        carta = self.deck.pop() 
        return carta
        
                

class Hand:
   
    def __init__(self):
        self.valor = 0
        self.aces = 0
        self.mano = []
        
    def __str__(self):
        mano_comp = ''
        for card in self.mano:
            mano_comp += '\n ' +card.__str__()
        return 'en la mano tenes: ' + mano_comp
    
    def add_card(self,card):
        self.mano.append(card)
        self.valor += values[card.numero]
        if card.numero == 'Ace':
            self.aces += 1  # add to self.aces
    
    def adjust_for_ace(self):
        while self.value > 21 and self.aces:
            self.value -= 10
            self.aces -= 1 


class Apuesta:
    
    def __init__(self):
        self.billetera = 100
        self.monto = 0
    def __str__(self):
        return self.billetera
    
    def apuesta(self):
    while True:
            try:
                chips.bet = int(input('How many chips would you like to bet? '))
            except ValueError:
                print('Sorry, a bet must be an integer!')
            else:
                if chips.bet > chips.total:
                    print("Sorry, your bet can't exceed",chips.total)
                else:
                    break        

   


       
        if self.monto > self.billetera:
            self.monto = int(input("cuanto apostas?, tenes {}".format(self.billetera))
        
    def win_bet(self):
        self.billetera += self.monto
    
    def lose_bet(self):
        self.billetera -= self.monto
     
#arranca
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}
playing =True
monedero = Apuesta()
test_deck = Deck()
test_deck.shuffle()
mano = Hand()
cpu = Hand()

while playing:

    mano.add_card(test_deck.deal())
    mano.add_card(test_deck.deal())
    
   
    cpu.add_card(test_deck.deal())
    cpu.add_card(test_deck.deal())


    
    print(mano)
    print(mano.valor)
    
    print(cpu)
    if mano.valor >= 21:
        playing = False
        print("you win")
        pass
# Out:
# en la mano tenes:
#  Hearts of Ace
#  Clubs of Three
# 14
# en la mano tenes:
#  Hearts of Two
#  Hearts of Three
# en la mano tenes:
#  Spades of Ace
#  Diamonds of King
# 21
# en la mano tenes:
#  Hearts of Queen
#  Diamonds of Ace
# you win
